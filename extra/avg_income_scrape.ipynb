# %% [markdown]
# # Scraping with Pandas

# %%
import pandas as pd

# %% [markdown]
# We can use the `read_html` function in Pandas to automatically scrape any tabular data from a page.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_U.S._states_by_income'

# %%
tables = pd.read_html(url)
my_table =tables[2]
my_table
# Out:
#        0                      1        2        3        4        5        6
# 0   Rank                  State     2015     2014     2013     2012     2011
# 1      1               Maryland  $75,847  $73,971  $72,483  $71,122  $70,004
# 2    NaN  District of Columbia†  $75,628  $71,648  $67,572  $66,583  $63,124
# 3      2                 Hawaii  $73,486  $69,592  $68,020  $66,259  $61,821
# 4      3                 Alaska  $73,355  $71,583  $72,237  $67,712  $67,825
# 5      4             New Jersey  $72,222  $71,919  $70,165  $69,667  $67,458
# 6      5            Connecticut  $71,346  $70,048  $67,098  $67,276  $65,753
# 7      6          Massachusetts  $70,628  $69,160  $66,768  $65,339  $62,859
# 8      7          New Hampshire  $70,303  $66,532  $64,230  $63,280  $62,647
# 9      8               Virginia  $66,262  $64,902  $62,666  $61,741  $61,882
# 10     9             California  $64,500  $61,933  $60,190  $58,328  $57,287
# ...

# %%
my_table.columns = ['Rank', 'State', '2015', '2014', 
              '2013', '2012','2011']
my_table.head()
# Out:
#    Rank                  State     2015     2014     2013     2012     2011
# 0  Rank                  State     2015     2014     2013     2012     2011
# 1     1               Maryland  $75,847  $73,971  $72,483  $71,122  $70,004
# 2   NaN  District of Columbia†  $75,628  $71,648  $67,572  $66,583  $63,124
# 3     2                 Hawaii  $73,486  $69,592  $68,020  $66,259  $61,821
# 4     3                 Alaska  $73,355  $71,583  $72,237  $67,712  $67,825

# %%
my_table = my_table.iloc[1:]

# %%
my_table.set_index('Rank', inplace=True)

# %%
my_table.to_csv('avg_income.csv',index=False)
